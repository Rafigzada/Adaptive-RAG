# %%
# %run run_rag.py

# %%
# %run benchmarking/squad_benchmark.py

# %%
# %run run_rag.py --interactive

# %%
# %run run_rag.py --interactive

# %%
# %run benchmarking/squad_benchmark.py
