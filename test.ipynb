# %%
# %run run_rag.py
# Out:
# 2025-06-21 03:07:15,310 - generation - INFO - AnswerGenerator initialized with default model: gemini-1.5-flash
# 2025-06-21 03:07:15,311 - caching - INFO - Loading cached 'document_summaries' data from rag_cache/summaries/document_summaries.joblib...
# 2025-06-21 03:07:15,311 - summarization - INFO - Document Summarizer model initialized (gemini-1.5-flash).
# 2025-06-21 03:07:15,311 - ranking - INFO - Document Re-ranker model initialized (gemini-1.5-flash).
# Starting RAG Demo with Gemini...
# Using PDF directory: /Users/satya.-./Advanced_RAG/pdfs
#
# Found 14 PDF files ready for processing:
#
# ======================================================================
# USING CLASS-BASED RAG PIPELINE
# ======================================================================
#
# Document Summarizer model initialized (gemini-1.5-flash).
# Document Re-ranker model initialized (gemini-1.5-flash).
#
# --- Initializing PDF Corpus ---
# Loading documents from ./pdfs...
# 2025-06-21 03:07:17,839 - caching - INFO - Loading cached 'pdf_full_doc_vectors' data from rag_cache/vectors/pdf_full_doc_vectors.joblib...
# 2025-06-21 03:07:17,846 - caching - INFO - Loading cached 'pdf_chunk_vectors' data from rag_cache/vectors/pdf_chunk_vectors.joblib...
# 2025-06-21 03:07:17,859 - caching - INFO - Saving 'document_summaries' data to cache (atomically) to rag_cache/summaries/document_summaries.joblib...
# 2025-06-21 03:07:17,860 - caching - INFO - Successfully saved 'document_summaries' data.
# 2025-06-21 03:07:17,861 - caching - INFO - Loading cached 'pdf_summary_tfidf' data from rag_cache/vectors/pdf_summary_tfidf.joblib...
# Summary: Loaded 14 existing PDF files.
#
# Loaded cached full document TF-IDF vectorizer.
# Full doc vectors shape: (14, 6627)
# Created 1153 chunks from 14 documents
#
# Loaded cached pdf chunk embeddings with shape (1153, 17270)
#
# --- PDF Corpus Initialization Completed! ---
#
# ======================================================================
# RUNNING COMPLETE RAG PIPELINE FOR: 'What are the main components of Retrieval-Augmented Generation?'
# ======================================================================
#
# --- Initial Full Document Relevance Check (TF-IDF) ---
#   Found 13 full documents with positive TF-IDF similarity.
#     Rank 1: Doc 'A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf' (Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf) - Score: 0.3237
#     Rank 2: Doc 'A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf' (Source: A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf) - Score: 0.2684
#     Rank 3: Doc 'Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf' (Source: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf) - Score: 0.2022
#     Rank 4: Doc 'ARAG_Presentation (1).pdf' (Source: ARAG_Presentation (1).pdf) - Score: 0.1580
#     Rank 5: Doc 'RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf' (Source: RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf) - Score: 0.1553
# --------------------------------------------------
#
#   **5 or more relevant full documents found. Proceeding with Document Summarization and Summary Pre-filter.**
#
# Generating summaries for 14 documents...
#
# Summary generation completed. 14 loaded from cache.
#
# Loaded cached summary TF-IDF vectorizer. Summary vectors shape: (14, 170)
#
# --- Pre-filtering Documents (by Summary TF-IDF) ---
#   - Document 2 ('RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf') - Score: 0.4712
#   - Document 11 ('A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf') - Score: 0.3278
#   - Document 12 ('Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf') - Score: 0.2685
#   - Document 1 ('A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf') - Score: 0.2508
#   - Document 8 ('ARAG_Presentation (1).pdf') - Score: 0.1872
# Found 5 documents relevant based on summaries.
#
# === RETRIEVAL PHASE for: 'What are the main components of Retrieval-Augmented Generation?' ===
# Retrieved chunk 1 (score: 0.2540):
# - From: 'A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf' (Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf)
# Retrieved chunk 2 (score: 0.2128):
# - From: 'ARAG_Presentation (1).pdf' (Source: ARAG_Presentation (1).pdf)
# Retrieved chunk 3 (score: 0.1860):
# - From: 'A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf' (Source: A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf)
# Retrieved chunk 4 (score: 0.1418):
# - From: 'A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf' (Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf)
# Retrieved chunk 5 (score: 0.1376):
# - From: 'Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf' (Source: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf)
# Retrieved chunk 6 (score: 0.1283):
# - From: 'A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf' (Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf)
# Retrieved chunk 7 (score: 0.1271):
# - From: 'Lightweight Relevance Grader in RAG.pdf' (Source: Lightweight Relevance Grader in RAG.pdf)
# Retrieved chunk 8 (score: 0.1266):
# - From: 'A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf' (Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf)
# Retrieved chunk 9 (score: 0.1251):
# - From: 'ARAG_Presentation (1).pdf' (Source: ARAG_Presentation (1).pdf)
# Retrieved chunk 10 (score: 0.1150):
# - From: 'Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf' (Source: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf)
# Retrieved chunk 11 (score: 0.1093):
# - From: 'SimpleDoc- Multi-Modal Document Understanding with Dual-Cue Page Retrieval and Iterative Refinement.pdf' (Source: SimpleDoc- Multi-Modal Document Understanding with Dual-Cue Page Retrieval and Iterative Refinement.pdf)
# Retrieved chunk 12 (score: 0.1087):
# - From: 'RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf' (Source: RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf)
# Retrieved chunk 13 (score: 0.1060):
# - From: 'ARAG_Presentation (1).pdf' (Source: ARAG_Presentation (1).pdf)
# Retrieved chunk 14 (score: 0.1049):
# - From: 'A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf' (Source: A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf)
# Retrieved chunk 15 (score: 0.1042):
# - From: 'RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf' (Source: RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf)
# Retrieved chunk 16 (score: 0.1041):
# - From: 'A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf' (Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf)
# Retrieved chunk 17 (score: 0.1036):
# - From: 'A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf' (Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf)
# Retrieved chunk 18 (score: 0.1036):
# - From: 'ARAG_Presentation (1).pdf' (Source: ARAG_Presentation (1).pdf)
# Retrieved chunk 19 (score: 0.1014):
# - From: 'A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf' (Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf)
# Retrieved chunk 20 (score: 0.1009):
# - From: 'A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf' (Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf)
# Retrieved chunk 21 (score: 0.0981):
# - From: 'A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf' (Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf)
# Retrieved chunk 22 (score: 0.0981):
# - From: 'AviationLLM- An LLM-based Knowledge System for Aviation Training.pdf' (Source: AviationLLM- An LLM-based Knowledge System for Aviation Training.pdf)
# Retrieved chunk 23 (score: 0.0968):
# - From: 'Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf' (Source: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf)
# Retrieved chunk 24 (score: 0.0958):
# - From: 'AviationLLM- An LLM-based Knowledge System for Aviation Training.pdf' (Source: AviationLLM- An LLM-based Knowledge System for Aviation Training.pdf)
# Retrieved chunk 25 (score: 0.0945):
# - From: 'A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf' (Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf)
# Retrieved chunk 26 (score: 0.0943):
# - From: 'Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf' (Source: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf)
# Retrieved chunk 27 (score: 0.0942):
# - From: 'Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf' (Source: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf)
# Retrieved chunk 28 (score: 0.0934):
# - From: 'Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf' (Source: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf)
# Retrieved chunk 29 (score: 0.0919):
# - From: 'RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf' (Source: RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf)
# Retrieved chunk 30 (score: 0.0918):
# - From: 'A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf' (Source: A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf)
# Retrieval completed in 0.0010 seconds
# ---------------------------------------------------------------
#
# Processed 26 chunks (after summary pre-filter) into 5 document groups for re-ranking.
#
# --- Document Groups Prepared for Re-ranking ---
#   Group 1:
#     Title: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf
#     Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf
#     Content Preview: ral
# new
# methods
# acro...
#     Length of Content: 2414
#   Group 2:
#     Title: ARAG_Presentation (1).pdf
#     Source: ARAG_Presentation (1).pdf
#     Content Preview: Retrieval -Augmented...
#     Length of Content: 1514
#   Group 3:
#     Title: A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf
#     Source: A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf
#     Content Preview: gure 2: Illustration...
#     Length of Content: 2414
#   Group 4:
#     Title: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf
#     Source: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf
#     Content Preview: ies, elucidating how...
#     Length of Content: 2414
#   Group 5:
#     Title: RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf
#     Source: RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf
#     Content Preview: nker Evaluation Gene...
#     Length of Content: 1514
# ---------------------------------------------------------------
#
# --- Re-ranking 5 Retrieved Documents ---
#     --- Sending Batch 1 to Re-ranker (Documents in this batch) ---
#     Document 1 in batch: 'A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf' (Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf)
#     Document 2 in batch: 'ARAG_Presentation (1).pdf' (Source: ARAG_Presentation (1).pdf)
#     Document 3 in batch: 'A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf' (Source: A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf)
#   -------------------------------------------------------------
#
#   - LLM Re-ranker Output(Score given by LLM on a scale of 1 to 5) for batch 1:
# Document 1: 5
# Document 3: 4
# Document 2: 2
#
#     --- Sending Batch 2 to Re-ranker (Documents in this batch) ---
#     Document 1 in batch: 'Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf' (Source: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf)
#     Document 2 in batch: 'RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf' (Source: RAGtifier- Evaluating RAG Generation Approaches of State-of-the-Art RAG Systems for the SIGIR LiveRAG Competition.pdf)
#   -------------------------------------------------------------
# 2025-06-21 03:07:19,487 - generation - INFO - --- GENERATION PHASE (Gemini SDK) ---
# 2025-06-21 03:07:19,489 - generation - INFO - Attempting Gemini API call (model: gemini-1.5-flash, stream: False)...
#   - LLM Re-ranker Output(Score given by LLM on a scale of 1 to 5) for batch 2:
# Document 1: 5
# Document 2: 4
#
#   - Total documents collected for re-ranking: 5
# Re-ranked to top 3 documents.
# Re-ranking completed in 1.6234 seconds.
#
#
# --- Re-ranked Documents (before final context slicing) ---
#     Rank 1 (Rerank Score: 5.00):
#     Title: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf
#     Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf
#     Content Preview: ral
# new
# methods
# across
# the
# RAG...
#     Length of Content: 2414
#     Rank 2 (Rerank Score: 5.00):
#     Title: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf
#     Source: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf
#     Content Preview: ies, elucidating how these com...
#     Length of Content: 2414
#     Rank 3 (Rerank Score: 4.00):
#     Title: A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf
#     Source: A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf
#     Content Preview: gure 2: Illustration of the ba...
#     Length of Content: 2414
# -------------------------------------------------------
# Using 3 documents for final context.
#
#
# --- Actual Final Context Documents Sent to LLM ---
#
#   Context Doc 1:
#     Title: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf
#     Source: A Comprehensive Survey of Retrieval-Augmented Generation (RAG)- Evolution, Current Landscape and Future Directions.pdf
#     Content Preview: ral
# new
# methods
# across
# the
# RAG...
#     Length of Content: 2414
#
#   Context Doc 2:
#     Title: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf
#     Source: Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf
#     Content Preview: ies, elucidating how these com...
#     Length of Content: 2414
#
#   Context Doc 3:
#     Title: A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf
#     Source: A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf
#     Content Preview: gure 2: Illustration of the ba...
#     Length of Content: 2414
# --------------------------------------------------
# 2025-06-21 03:07:20,716 - generation - INFO - Generated answer in 1.2275 seconds (model: gemini-1.5-flash).
# === FINAL RESULT ===
# Query: What are the main components of Retrieval-Augmented Generation?
# Answer: Retrieval-Augmented Generation (RAG) has two main components:  a retrieval mechanism that accesses relevant information from an external knowledge source [1], and a generation module that processes this information to produce human-like text [1].  Some sources also identify a third component, "augmentation," which describes how the retrieved information is integrated into the generation process [2, 3].  The exact implementation of these components can vary, with some systems employing modular designs with additional specialized components [2].
#
# Performance Metrics:
# - Initial Full Doc Relevance Check time: 0.0037s
# - Summarization (if used) time: 0.0024s
# - Pre-filter (Summary TF-IDF if used) time: 0.0005s
# - Retrieval (Chunk TF-IDF) time: 0.0010s
# - Processing (Merging chunks) time: 0.0000s
# - Re-ranking time: 1.6234s
# - Prompt creation time: 0.0010s
# - Generation time: 1.2275s
# - Total pipeline time: 2.8595s
#
# ======================================================================
#
#
# === CLASS-BASED PIPELINE RESULTS ===
#                                                           Query                                                                                                  Answer  Retrieval Time (s)  Processing Time (s)  Prompt Time (s)  Generation Time (s)  Total Time (s)
# What are the main components of Retrieval-Augmented Generation? Retrieval-Augmented Generation (RAG) has two main components:  a retrieval mechanism that accesses r...            0.001035             0.000017            0.001             1.227479        2.859486
#
# Average Performance Metrics:
# - Avg Retrieval: 0.0010s
# - Avg Processing: 0.0000s
# - Avg Prompt: 0.0010s
# - Avg Generation: 1.2275s
# - Avg Total: 2.8595s

# %%
# %run benchmarking/squad_benchmark.py

# %%
# %run run_rag.py --interactive

# %%
# %run run_rag.py --interactive

# %%
# %run benchmarking/squad_benchmark.py
