# %%
# %run run_rag.py
# Out:
# 2025-06-09 13:46:44,457 - generation - INFO - AnswerGenerator initialized with default model: gemini-1.5-flash
# 2025-06-09 13:46:44,457 - summarization - INFO - Document Summarizer model initialized (gemini-1.5-flash).
# 2025-06-09 13:46:44,457 - ranking - INFO - Document Re-ranker model initialized (gemini-1.5-flash).
# Starting RAG Demo with Gemini...
# Using PDF directory: /Users/satya.-./Advanced_RAG/pdfs
#
# Found 2 PDF files ready for processing:
#   - A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf
#   - Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf
#
# ...
# USING CLASS-BASED RAG PIPELINE
# ...
#
# Document Summarizer model initialized (gemini-1.5-flash).
# Document Re-ranker model initialized (gemini-1.5-flash).
#
# --- Initializing RAG Pipeline ---
# Loading documents from ./pdfs...
# Loaded PDF: ./pdfs/A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf (11 pages, 83049 characters)
# ...

# %%
# %run run_rag.py --interactive
# Out:
# Starting Interactive RAG Mode...
# Enter PDF directory path (default: ./pdfs):
#
# Enter Gemini model name (default: gemini-1.5-flash-latest):  gemini-2.0-flash
# 2025-06-09 13:47:42,451 - generation - INFO - AnswerGenerator initialized with default model: gemini-2.0-flash
# 2025-06-09 13:47:42,452 - summarization - INFO - Document Summarizer model initialized (gemini-2.0-flash).
# 2025-06-09 13:47:42,453 - ranking - INFO - Document Re-ranker model initialized (gemini-2.0-flash).
# Using PDF directory: /Users/satya.-./Advanced_RAG/pdfs
#
# Found 2 PDF files ready for processing:
#   - A Survey on RAG Meeting LLMs Towards Retrieval-Augmented Large Language Models (3).pdf
#   - Retrieval-Augmented Generation for Large Language Models A Survey (3).pdf
#
# Document Summarizer model initialized (gemini-2.0-flash).
# Document Re-ranker model initialized (gemini-2.0-flash).
#
# --- Initializing RAG Pipeline ---
# Loading documents from ./pdfs...
# ...

# %%
# %run benchmarking/squad_benchmark.py
# Out:
# README.md:   0%|          | 0.00/7.62k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# ...
# Generating validation split:   0%|          | 0/10570 [00:00<?, ? examples/s]
# 2025-06-09 13:52:36,255 - generation - INFO - AnswerGenerator initialized with default model: gemini-1.5-flash
# 2025-06-09 13:52:36,255 - summarization - INFO - Document Summarizer model initialized (gemini-1.5-flash).
# 2025-06-09 13:52:36,255 - ranking - INFO - Document Re-ranker model initialized (gemini-1.5-flash).
# Document Summarizer model initialized (gemini-1.5-flash).
# Document Re-ranker model initialized (gemini-1.5-flash).
# 🔍 Loading Wikipedia articles...
# 🔍 Loading 50 Wikipedia articles...
# README.md:   0%|          | 0.00/16.0k [00:00<?, ?B/s]
# wikipedia.py:   0%|          | 0.00/36.7k [00:00<?, ?B/s]
# ✅ Loaded 50 Wikipedia articles (streamed).
# ...
